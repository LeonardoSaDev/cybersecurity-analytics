# %% [markdown]
# # Transformações Avançadas

# %%
from pathlib import Path
import sys
sys.path.append(str(Path("..") / "src"))
from etl_pipeline import load_raw_csvs, transform
df = load_raw_csvs()
custom = lambda d: d
df2 = transform(df, transformer=custom)
df2.head()
