# %% [markdown]
# # Visualizações

# %%
from pathlib import Path
import sys
sys.path.append(str(Path("..") / "src"))
from etl_pipeline import load_raw_csvs
from analytics import histogram
df = load_raw_csvs()
out = None
cols = list(df.columns) if not df.empty else []
if cols:
    out = histogram(df, cols[0])
out
